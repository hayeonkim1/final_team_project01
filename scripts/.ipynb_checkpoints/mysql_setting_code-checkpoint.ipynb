# %%
pip install pymysql sqlalchemy pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#1 네이버 

import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "zimtori_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "naver_keyword"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\당근,중고,에타,네이버 csv파일(최종)\네이버_검색어_키워드__정제_final.csv"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
# -------------------------------------------------------------------------
MYSQL_DATE_COLUMN_NAME = "posted_at" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\당근,중고,에타,네이버 csv파일(최종)\네이버_검색어_키워드__정제_final.csv
#    -> 성공적으로 1533건의 데이터를 로드했습니다.
#    -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['post_id', 'platform_id', 'platform_name', 'source_type', 'keyword', 'keyword_group', 'keyword_group_name', 'title', 'content_text', 'content_url', 'source_name', 'posted_at']
# 🚀 MySQL 데이터베이스의 'naver_keyword' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 1533건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
#1 당근&중고나라 kw2

import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "zimtori_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "carrot_joongna_kw2"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\당근,중고,에타,네이버 csv파일(최종)\당근__중고나라_KW2.csv"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
# -------------------------------------------------------------------------
MYSQL_DATE_COLUMN_NAME = "posted_at" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\당근,중고,에타,네이버 csv파일(최종)\당근__중고나라_KW2.csv
#    -> 성공적으로 15356건의 데이터를 로드했습니다.
#    -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['post_id', 'platform_id', 'platform_name', 'keyword', 'title', 'content_text', 'view_count', 'comment_count', 'posted_at', 'region', 'like_count', 'price']
# 🚀 MySQL 데이터베이스의 'carrot_joongna_kw2' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 15356건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
#1 당근&중고나라 kw2

import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "zimtori_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "carrot_joongna_kw1"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\당근,중고,에타,네이버 csv파일(최종)\당근_중고나라_KW1.csv"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
# -------------------------------------------------------------------------
MYSQL_DATE_COLUMN_NAME = "posted_at" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\당근,중고,에타,네이버 csv파일(최종)\당근_중고나라_KW1.csv
#    -> 성공적으로 10109건의 데이터를 로드했습니다.
#    -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['post_id', 'platform_id', 'platform_name', 'keyword', 'title', 'content_text', 'view_count', 'comment_count', 'posted_at', 'region', 'like_count', 'price']
# 🚀 MySQL 데이터베이스의 'carrot_joongna_kw1' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 10109건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
#1 에브리타임 kw1

import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "zimtori_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "everytime_kw1"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\당근,중고,에타,네이버 csv파일(최종)\에브리타임_1.csv"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
# -------------------------------------------------------------------------
MYSQL_DATE_COLUMN_NAME = "posted_at" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\당근,중고,에타,네이버 csv파일(최종)\에브리타임_1.csv
#    -> 성공적으로 596건의 데이터를 로드했습니다.
#    -> 🔄 컬럼명을 MySQL 규격인 'posted_at'(으)로 변환 완료!
# 🚀 MySQL 데이터베이스의 'everytime_kw1' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 596건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
#1 에브리타임 kw2

import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "zimtori_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "everytime_kw2"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\당근,중고,에타,네이버 csv파일(최종)\에브리타임_2.csv"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
# -------------------------------------------------------------------------
MYSQL_DATE_COLUMN_NAME = "posted_at" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\당근,중고,에타,네이버 csv파일(최종)\에브리타임_2.csv
#    -> 성공적으로 193건의 데이터를 로드했습니다.
#    -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['content_id', 'platform_id', 'platform_name', 'keyword', 'title', 'content_text', 'comment_count', 'posted_at']
# 🚀 MySQL 데이터베이스의 'everytime_kw2' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 193건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
#1 에브리타임 kw2

import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "zimtori_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "platform_category"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\platform_category.xlsx"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
# -------------------------------------------------------------------------
MYSQL_DATE_COLUMN_NAME = "posted_at" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\platform_category.xlsx
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[6], line 33
#      32 try:
# ---> 33     df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
#      34 except UnicodeDecodeError:
#
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          # MySQL 아이디
DB_PASS = "Hayeon123!"      # MySQL 비밀번호
DB_HOST = "localhost"     # 호스트 주소
DB_PORT = "3306"          # MySQL 포트 번호
DB_NAME = "zimtori_dataproject"   # 이미 만들어두신 DB 이름
TABLE_NAME = "platform_category"   # MySQL에 생성할(혹은 생성된) 테이블 이름

# [확인] 최종 확정된 엑셀 파일 절대 경로 (따옴표 완벽 마감)
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\platform_category.xlsx"

# -------------------------------------------------------------------------
# 2. 엑셀 파일 읽어오기 (read_excel 사용)
# -------------------------------------------------------------------------
print(f"📖 엑셀 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# read_csv 대신 read_excel을 사용하여 openpyxl 엔진으로 안전하게 읽어옵니다.
df = pd.read_excel(EXCEL_FILE_PATH)

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 테이블이 이미 있으면 데이터만 뒤에 이어서 붙임
        index=False          # 데이터프레임의 숫자 인덱스는 DB에 저장하지 않음
    )
    print(f"\n🎉 [대성공] 엑셀에 있던 {len(df)}건의 데이터가 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ DB 전송 중 에러 발생: {e}")
# Out:
# 📖 엑셀 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\platform_category.xlsx
#    -> 성공적으로 4건의 데이터를 로드했습니다.
# 🚀 MySQL 데이터베이스의 'platform_category' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 엑셀에 있던 4건의 데이터가 MySQL DB로 무사히 이전되었습니다!

# %%
import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "zimtori_dataproject"   
TABLE_NAME = "keyword_category"   

EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\keyword_category.xlsx"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름을 여기에 적어주세요!
# -------------------------------------------------------------------------
# # 예: 테이블 만들 때 'posted_at'으로 만드셨다면 "posted_at"이라고 적으시면 됩니다.
# MYSQL_DATE_COLUMN_NAME = "posted_at" 

# -------------------------------------------------------------------------
# 2. 엑셀 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 엑셀 파일을 불러오는 중: {EXCEL_FILE_PATH}")
df = pd.read_excel(EXCEL_FILE_PATH)
print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 엑셀의 'date' 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 엑셀 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  
        index=False          
    )
    print(f"\n🎉 [대성공] 엑셀에 있던 {len(df)}건의 데이터가 명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 지정하신 날짜 컬럼명이나 다른 컬럼들의 스펠링이 MySQL 테이블과 완벽히 일치하는지 확인해 주세요.")
# Out:
# 📖 엑셀 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\keyword_category.xlsx
#    -> 성공적으로 30건의 데이터를 로드했습니다.
#    -> ⚠️ 엑셀 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['kw_id', 'kw_category', 'keyword_text', 'platform_id']
# 🚀 MySQL 데이터베이스의 'keyword_category' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 엑셀에 있던 30건의 데이터가 명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "final_dataproject"   
TABLE_NAME = "everytime_rental"   

EXCEL_FILE_PATH = r"C:\Users\HJkim\final_project_my\final_team_project01\data\everytime_houserental_crawling.xlsx"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름을 여기에 적어주세요!
# -------------------------------------------------------------------------
# 예: 테이블 만들 때 'posted_at'으로 만드셨다면 "posted_at"이라고 적으시면 됩니다.
MYSQL_DATE_COLUMN_NAME = "posted_at" 

# -------------------------------------------------------------------------
# 2. 엑셀 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 엑셀 파일을 불러오는 중: {EXCEL_FILE_PATH}")
df = pd.read_excel(EXCEL_FILE_PATH)
print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 엑셀의 'date' 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 엑셀 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  
        index=False          
    )
    print(f"\n🎉 [대성공] 엑셀에 있던 {len(df)}건의 데이터가 명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 지정하신 날짜 컬럼명이나 다른 컬럼들의 스펠링이 MySQL 테이블과 완벽히 일치하는지 확인해 주세요.")
# Out:
# 📖 엑셀 파일을 불러오는 중: C:\Users\HJkim\final_project_my\final_team_project01\data\everytime_houserental_crawling.xlsx
#    -> 성공적으로 596건의 데이터를 로드했습니다.
#    -> 🔄 엑셀의 'date' 컬럼명을 MySQL 규격인 'posted_at'(으)로 변환 완료!
# 🚀 MySQL 데이터베이스의 'everytime_rental' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 엑셀에 있던 596건의 데이터가 명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "final_dataproject"   
TABLE_NAME = "joongna.daangn_cleaning"   

EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\combined_joongna_daangn\KW1.csv"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름을 여기에 적어주세요!
# -------------------------------------------------------------------------
# 예: 테이블 만들 때 'posted_at'으로 만드셨다면 "posted_at"이라고 적으시면 됩니다.
MYSQL_DATE_COLUMN_NAME = "posted_date" 

# -------------------------------------------------------------------------
# 2. 엑셀 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 엑셀 파일을 불러오는 중: {EXCEL_FILE_PATH}")
df = pd.read_excel(EXCEL_FILE_PATH)
print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 엑셀의 'date' 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 엑셀 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  
        index=False          
    )
    print(f"\n🎉 [대성공] 엑셀에 있던 {len(df)}건의 데이터가 명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 지정하신 날짜 컬럼명이나 다른 컬럼들의 스펠링이 MySQL 테이블과 완벽히 일치하는지 확인해 주세요.")
# Out:
# 📖 엑셀 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\combined_joongna_daangn\KW1.csv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 26
#      22 # -------------------------------------------------------------------------
#      23 # 2. 엑셀 파일 읽기 및 컬럼명 자동 변환
#      24 # -------------------------------------------------------------------------
#      25 print(f"📖 엑셀 파일을 불러오는 중: {EXCEL_FILE_PATH}")
# ---> 26 df = pd.read_excel(EXCEL_FILE_PATH)
#      27 print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")
#      29 # [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
#
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "final_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "joongna_daangn_cleaning"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\combined_joongna_daangn\KW1.csv"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
# -------------------------------------------------------------------------
MYSQL_DATE_COLUMN_NAME = "posted_date" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\combined_joongna_daangn\KW1.csv
#    -> 성공적으로 10109건의 데이터를 로드했습니다.
#    -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['post_id', 'platform', 'keyword', 'title', 'content_text', 'view_count', 'comment_count', 'posted_date', 'region', 'like_count', 'price']
# 🚀 MySQL 데이터베이스의 'joongna_daangn_cleaning' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 10109건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "final_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "joongna_daangn_usage"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\combined_joongna_daangn\KW2.csv"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
# -------------------------------------------------------------------------
MYSQL_DATE_COLUMN_NAME = "posted_date" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\combined_joongna_daangn\KW2.csv
#    -> 성공적으로 15356건의 데이터를 로드했습니다.
#    -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['post_id', 'platform', 'keyword', 'title', 'content_text', 'view_count', 'comment_count', 'posted_date', 'region', 'like_count', 'price']
# 🚀 MySQL 데이터베이스의 'joongna_daangn_usage' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 15356건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "final_dataproject"   
TABLE_NAME = "dabang_housing"   

EXCEL_FILE_PATH = r"C:\Users\HJkim\final_teamprojcet\data\dabang_region_summary_v6_completed.xlsx"


# -------------------------------------------------------------------------
# 2. 엑셀 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 엑셀 파일을 불러오는 중: {EXCEL_FILE_PATH}")
df = pd.read_excel(EXCEL_FILE_PATH)
print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 엑셀의 'date' 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 엑셀 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  
        index=False          
    )
    print(f"\n🎉 [대성공] 엑셀에 있던 {len(df)}건의 데이터가 명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 지정하신 날짜 컬럼명이나 다른 컬럼들의 스펠링이 MySQL 테이블과 완벽히 일치하는지 확인해 주세요.")
# Out:
# 📖 엑셀 파일을 불러오는 중: C:\Users\HJkim\final_teamprojcet\data\dabang_region_summary_v6_completed.xlsx
#    -> 성공적으로 25건의 데이터를 로드했습니다.
#    -> ⚠️ 엑셀 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['collected_at', 'region_sido', 'region_sigungu', 'monthly_listing_count', 'short_month_listing_count', 'short_month_ratio']
# 🚀 MySQL 데이터베이스의 'dabang_housing' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 엑셀에 있던 25건의 데이터가 명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "final_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "dalock_price"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_project_my\final_team_project01\dalock_lowestprice_list.csv"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
# -------------------------------------------------------------------------
# MYSQL_DATE_COLUMN_NAME = "posted_date" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_project_my\final_team_project01\dalock_lowestprice_list.csv
#    -> 성공적으로 204건의 데이터를 로드했습니다.
#    -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['branch_name', 'unit_type', 'discount_price']
# 🚀 MySQL 데이터베이스의 'dalock_price' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 204건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "final_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "dalock_reviews"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_project_my\final_team_project01\google_play_reviews_filtered.csv"

# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
# -------------------------------------------------------------------------
# MYSQL_DATE_COLUMN_NAME = "posted_date" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_project_my\final_team_project01\google_play_reviews_filtered.csv
#    -> 성공적으로 122건의 데이터를 로드했습니다.
#    -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['작성자', '별점', '리뷰내용', '작성일']
# 🚀 MySQL 데이터베이스의 'dalock_reviews' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 122건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!

# %%
import pandas as pd
from sqlalchemy import create_engine

# -------------------------------------------------------------------------
# [설정 항목] 1. 본인의 MySQL 접속 정보 입력
# -------------------------------------------------------------------------
DB_USER = "root"          
DB_PASS = "Hayeon123!"      
DB_HOST = "localhost"     
DB_PORT = "3306"          
DB_NAME = "final_dataproject"   

# [수정] 테이블 이름의 쉼표(,)를 언더바(_)로 교정 (실제 DB 테이블명과 일치시키세요)
TABLE_NAME = "naver_keyword"   

# 대상 파일이 .csv 파일임을 확인
EXCEL_FILE_PATH = r"C:\Users\HJkim\final_project_my\final_team_project01\네이버 검색어 키워드_ 정제_final.csv"
# -------------------------------------------------------------------------
# [설정 항목] 2. 실제 MySQL 테이블에 작성된 날짜 컬럼의 이름
#-------------------------------------------------------------------------
MYSQL_DATE_COLUMN_NAME = "posted_at" 

# -------------------------------------------------------------------------
# 2. CSV 파일 읽기 및 컬럼명 자동 변환
# -------------------------------------------------------------------------
print(f"📖 CSV 파일을 불러오는 중: {EXCEL_FILE_PATH}")

# [수정] .csv 파일이므로 read_csv를 사용하며, 인코딩 에러 방지용 코드를 추가합니다.
try:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='utf-8-sig')
except UnicodeDecodeError:
    df = pd.read_csv(EXCEL_FILE_PATH, encoding='cp949')

print(f"   -> 성공적으로 {len(df)}건의 데이터를 로드했습니다.")

# [💡 핵심 교정 작업] 엑셀의 'date' 컬럼 이름을 MySQL 컬럼 이름으로 변경합니다.
if 'date' in df.columns:
    df = df.rename(columns={'date': MYSQL_DATE_COLUMN_NAME})
    print(f"   -> 🔄 컬럼명을 MySQL 규격인 '{MYSQL_DATE_COLUMN_NAME}'(으)로 변환 완료!")
else:
    print("   -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록:", list(df.columns))

# -------------------------------------------------------------------------
# 3. SQLAlchemy를 이용한 MySQL 커넥션 엔진 생성
# -------------------------------------------------------------------------
db_connection_str = f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
engine = create_engine(db_connection_str)

# -------------------------------------------------------------------------
# 4. MySQL DB에 통째로 밀어넣기
# -------------------------------------------------------------------------
print(f"🚀 MySQL 데이터베이스의 '{TABLE_NAME}' 테이블로 전송을 시작합니다...")

try:
    df.to_sql(
        name=TABLE_NAME, 
        con=engine, 
        if_exists='append',  # 이미 테이블이 존재하면 이어서 데이터 추가
        index=False          
    )
    print(f"\n🎉 [대성공] {len(df)}건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!")

except Exception as e:
    print(f"\n❌ 여전히 DB 전송 중 에러 발생: {e}")
    print("👉 조치 팁: 데이터 유실 우려가 없다면 'if_exists=append'를 'if_exists=replace'로 바꾸어 실행하면 테이블을 자동 재생성해 줍니다.")
# Out:
# 📖 CSV 파일을 불러오는 중: C:\Users\HJkim\final_project_my\final_team_project01\네이버 검색어 키워드_ 정제_final.csv
#    -> 성공적으로 1533건의 데이터를 로드했습니다.
#    -> ⚠️ 파일에 'date' 컬럼이 존재하지 않습니다. 기존 컬럼명 목록: ['post_id', 'platform', 'source_type', 'keyword', 'keyword_group', 'keyword_group_name', 'title', 'content_text', 'content_url', 'source_name', 'posted_at']
# 🚀 MySQL 데이터베이스의 'naver_keyword' 테이블로 전송을 시작합니다...
#
# 🎉 [대성공] 1533건의 데이터가 파일 형식/명칭 불일치를 극복하고 MySQL DB로 무사히 이전되었습니다!
